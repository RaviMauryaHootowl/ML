# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### We will use california housing dataset for our network

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()  # this is a dictionary

# %% [markdown]
# No. of instances = 20640

# %% [markdown]
# there are 8 features in this model and the target

# %% [markdown]
# #### for more details refer the url
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_california_housing.html

# %%
print(housing.feature_names) # feature names
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %% [markdown]
# ### Now we will split our data

# %%
from sklearn.model_selection import train_test_split
X_train_full,X_test,Y_train_full,Y_test=train_test_split(housing.data,housing.target,random_state=42)
X_train,X_valid,Y_train,Y_valid=train_test_split(X_train_full,Y_train_full,random_state=42)

# %% [markdown]
# 25% data becomes test data and rest becomes training data

# %% [markdown]
# out of that 75% , 25% goes into validation and rest goes to training data

# %% [markdown]
# ### Now we will standardize the data (feature scaling)
# We subtract the mean with the original values and then we divide it by the variance
# this is done so that the cost function curve converges faster giving faster results

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_valid=scaler.transform(X_valid)
X_test=scaler.transform(X_test)

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
X_train.shape
# Out:
# (11610, 8)

# %% [markdown]
# ### Now we will create the structure for our Functional API NN

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:]) # 8 feature input layer
hidden1 = keras.layers.Dense(30,activation="relu")(input_)
hidden2 = keras.layers.Dense(30,activation="relu")(hidden1)
concat = keras.layers.concatenate([input_,hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.models.Model(inputs=[input_],outputs=[output])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           270         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           930         dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38)           0           input_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            39          concatenate[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss="mean_squared_error",
              optimizer=keras.optimizers.SGD(lr=1e-3), # schocastic gradient descent
              metrics=['mae'])  # mean absolute error

# %% [markdown]
# ### We will now train the model

# %%
model_history=model.fit(X_train,Y_train,epochs=40,validation_data=(X_valid,Y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/40
# 11610/11610 [==============================] - 2s 201us/sample - loss: 1.2474 - mae: 0.7958 - val_loss: 0.8727 - val_mae: 0.5975
# Epoch 2/40
# 11610/11610 [==============================] - 1s 128us/sample - loss: 0.6341 - mae: 0.5799 - val_loss: 0.8881 - val_mae: 0.5628
# Epoch 3/40
# 11610/11610 [==============================] - 2s 131us/sample - loss: 0.5885 - mae: 0.5552 - val_loss: 0.5573 - val_mae: 0.5347
# Epoch 4/40
# 11610/11610 [==============================] - 2s 133us/sample - loss: 0.5599 - mae: 0.5411 - val_loss: 0.5238 - val_mae: 0.5185
# Epoch 5/40
# 11610/11610 [==============================] - 2s 132us/sample - loss: 0.5367 - mae: 0.5288 - val_loss: 0.6201 - val_mae: 0.5152
# Epoch 6/40
# 11610/11610 [==============================] - 2s 136us/sample - loss: 0.5170 - mae: 0.5173 - val_loss: 0.4979 - val_mae: 0.5012
# Epoch 7/40
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.5022 - mae: 0.5120 - val_loss: 0.5240 - val_mae: 0.4968
# Epoch 8/40
# Epoch 26/40
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3920 - mae: 0.4476 - val_loss: 0.3820 - val_mae: 0.4328
# Epoch 27/40
# 11610/11610 [==============================] - 1s 113us/sample - loss: 0.3900 - mae: 0.4456 - val_loss: 0.3634 - val_mae: 0.4299
# Epoch 28/40
# 11610/11610 [==============================] - 1s 115us/sample - loss: 0.3875 - mae: 0.4442 - val_loss: 0.3735 - val_mae: 0.4301
# Epoch 29/40
# 11610/11610 [==============================] - 1s 123us/sample - loss: 0.3856 - mae: 0.4426 - val_loss: 0.3724 - val_mae: 0.4317
# Epoch 30/40
# 11610/11610 [==============================] - 1s 127us/sample - loss: 0.3837 - mae: 0.4418 - val_loss: 0.3631 - val_mae: 0.4265
# Epoch 31/40
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3816 - mae: 0.4400 - val_loss: 0.3811 - val_mae: 0.4292
# Epoch 32/40
# 11610/11610 [==============================] - 1s 123us/sample - loss: 0.3797 - mae: 0.4386 - val_loss: 0.3610 - val_mae: 0.4237
# Epoch 33/40
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.3780 - mae: 0.4371 - val_loss: 0.3541 - val_mae: 0.4239
# Epoch 34/40
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3763 - mae: 0.4362 - val_loss: 0.3651 - val_mae: 0.4245
# Epoch 35/40
# 11610/11610 [==============================] - 1s 113us/sample - loss: 0.3750 - mae: 0.4344 - val_loss: 0.3522 - val_mae: 0.4238
# Epoch 36/40
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.3731 - mae: 0.4336 - val_loss: 0.3515 - val_mae: 0.4220
# Epoch 37/40
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3712 - mae: 0.4324 - val_loss: 0.3821 - val_mae: 0.4288
# Epoch 38/40
# 11610/11610 [==============================] - 1s 126us/sample - loss: 0.3705 - mae: 0.4320 - val_loss: 0.3631 - val_mae: 0.4229
# Epoch 39/40
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.3690 - mae: 0.4308 - val_loss: 0.3463 - val_mae: 0.4175
# Epoch 40/40
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3678 - mae: 0.4298 - val_loss: 0.3478 - val_mae: 0.4156

# %%
mae_test=model.evaluate(X_test,Y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %% [markdown]
# ### We will now visualise the model loss

# %%
pd.DataFrame(model_history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)

plt.show()

# %%
X_new=X_test[:3]

# %%
Y_pred=model.predict(X_new)
print(Y_pred)
print(Y_test[:3])
# Out:
# [[0.5652569]
#  [1.9270452]
#  [3.6875129]]
# [0.477   0.458   5.00001]

# %% [markdown]
# ### Saving the model

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
